# %%
import pandas as pd

# %%
df = pd.read_csv('/home/quanpv/PycharmProjects/admission_chatbot/uac/storage/data.csv')

df
# Out:
#                                                  Title  \
# 0                 CÁC NGÀNH ĐÀO TẠO CỦA ĐẠI HỌC ĐÔNG Á
# 1               các tổ hợp xét tuyển gồm những môn nào
# 2                                    các ngành đào tạo
# 3                                      mã ngành Y khoa
# 4                                        mã ngành Dược
# ..                                                 ...
# 731               Phương thức xét tuyển đại học đông á
# 732  xét tuyển kết theo kết quả kỳ thi tốt nghiệp THPT
# 733  xét tuyển theo kết quả kỳ thi đánh giá năng lự...
# 734                              Xét tuyển theo học bạ
# 735    trường đại học đông á xét tuyển bao nhiêu ngành
#
#                                                   Text  Unnamed: 2
# 0    các ngành đạo Đại học bao gồm:\n\n- Y KHOA mã ...         NaN
# 1    A00: Toán, Lý, Hóa | A01: Toán, Lý, Anh | A16:...         NaN
# 2    Y khoa, Dược, Điều dưỡng, Dinh dưỡng, Kỹ thuật...         NaN
# ...

# %%
df.drop_duplicates(inplace=True)

df
# Out:
#                                                  Title  \
# 0                 CÁC NGÀNH ĐÀO TẠO CỦA ĐẠI HỌC ĐÔNG Á
# 1               các tổ hợp xét tuyển gồm những môn nào
# 2                                    các ngành đào tạo
# 3                                      mã ngành Y khoa
# 4                                        mã ngành Dược
# ..                                                 ...
# 731               Phương thức xét tuyển đại học đông á
# 732  xét tuyển kết theo kết quả kỳ thi tốt nghiệp THPT
# 733  xét tuyển theo kết quả kỳ thi đánh giá năng lự...
# 734                              Xét tuyển theo học bạ
# 735    trường đại học đông á xét tuyển bao nhiêu ngành
#
#                                                   Text  Unnamed: 2
# 0    các ngành đạo Đại học bao gồm:\n\n- Y KHOA mã ...         NaN
# 1    A00: Toán, Lý, Hóa | A01: Toán, Lý, Anh | A16:...         NaN
# 2    Y khoa, Dược, Điều dưỡng, Dinh dưỡng, Kỹ thuật...         NaN
# ...
